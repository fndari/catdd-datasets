# %%
import requests
import requests_cache
requests_cache.install_cache('calrecycle')
import pandas as pd
import time

# %%
URL = 'https://www2.calrecycle.ca.gov/LGCentral/DisposalReporting/Destination/CountywideSummary'
params = {'CountyID': 58, 'ReportFormat': 'XLS'}
resp = requests.post(URL, data=params)
resp
# Out:
# <Response [200]>

# %%
import io

# %%
def set_columns(df, columns=None, row_idx=None):
    df = df.copy()
    if row_idx:
        columns = df.iloc[row_idx, :].tolist()
    df.columns = columns
    return df

# %%
(pd.read_excel(io.BytesIO(resp.content))
#  .iloc[4,:].tolist()
 .pipe(set_columns, row_idx=4)
 .iloc[5:, :]
 .dropna(axis=1, how='all')
 .assign(is_data_row=lambda d: d['Destination Facility'].notnull())
 .fillna(method='ffill')
 .query('is_data_row')
)
# Out:
# WARNING *** file size (47797) not 512 + multiple of sector size (512)
#      Report Year  Quarter           Destination Facility  Diposal Ton  \
# 7           1995      1.0  Recology Yuba-Sutter Landfill     29594.00
# 8           1995      1.0      Yuba-Sutter Disposal Area       629.00
# 10          1995      2.0  Recology Yuba-Sutter Landfill     31012.00
# 11          1995      2.0      Yuba-Sutter Disposal Area       725.90
# 13          1995      3.0   Recology Ostrom Road LF Inc.     21288.00
# 14          1995      3.0  Recology Yuba-Sutter Landfill     11319.00
# 15          1995      3.0      Yuba-Sutter Disposal Area       830.00
# 17          1995      4.0   Recology Ostrom Road LF Inc.      6152.00
# 18          1995      4.0  Recology Yuba-Sutter Landfill     26269.00
# 21          1996      1.0  Recology Yuba-Sutter Landfill     32912.00
# 23          1996      2.0   Recology Ostrom Road LF Inc.      4982.00
# 24          1996      2.0  Recology Yuba-Sutter Landfill     31010.00
# 26          1996      3.0   Recology Ostrom Road LF Inc.     29585.00
# 27          1996      3.0  Recology Yuba-Sutter Landfill      8212.00
# 29          1996      4.0   Recology Ostrom Road LF Inc.     14672.00
# 30          1996      4.0  Recology Yuba-Sutter Landfill     19071.37
# 33          1997      1.0   Recology Ostrom Road LF Inc.     48905.40
# 35          1997      2.0   Recology Ostrom Road LF Inc.     40133.00
# 37          1997      3.0   Recology Ostrom Road LF Inc.     43939.00
# 39          1997      4.0   Recology Ostrom Road LF Inc.     37780.00
# 42          1998      1.0   Recology Ostrom Road LF Inc.     33729.00
# 44          1998      2.0   Recology Ostrom Road LF Inc.     42294.00
# 46          1998      3.0   Recology Ostrom Road LF Inc.     52216.00
# 48          1998      4.0   Recology Ostrom Road LF Inc.     48672.80
# 51          1999      1.0   Recology Ostrom Road LF Inc.     43946.00
# 53          1999      2.0   Recology Ostrom Road LF Inc.     46122.00
# 55          1999      3.0   Recology Ostrom Road LF Inc.     51663.00
# 57          1999      4.0   Recology Ostrom Road LF Inc.     47446.00
# 60          2000      1.0   Recology Ostrom Road LF Inc.     45796.00
# 62          2000      2.0   Recology Ostrom Road LF Inc.     49540.00
# ..           ...      ...                            ...          ...
# 154         2010      3.0   Recology Ostrom Road LF Inc.     61801.43
# 156         2010      4.0   Recology Ostrom Road LF Inc.     57671.03
# 159         2011      1.0   Recology Ostrom Road LF Inc.     54452.33
# 161         2011      2.0   Recology Ostrom Road LF Inc.     56079.63
# 163         2011      3.0   Recology Ostrom Road LF Inc.     59165.16
# 165         2011      4.0   Recology Ostrom Road LF Inc.     60084.97
# 168         2012      1.0   Recology Ostrom Road LF Inc.     58138.58
# 170         2012      2.0   Recology Ostrom Road LF Inc.     58517.02
# 172         2012      3.0   Recology Ostrom Road LF Inc.     55890.99
# 174         2012      4.0   Recology Ostrom Road LF Inc.     49501.82
# 177         2013      1.0   Recology Ostrom Road LF Inc.     45223.77
# 179         2013      2.0   Recology Ostrom Road LF Inc.     47736.47
# 181         2013      3.0   Recology Ostrom Road LF Inc.     51176.23
# 183         2013      4.0   Recology Ostrom Road LF Inc.     45812.02
# 186         2014      1.0   Recology Ostrom Road LF Inc.     46968.50
# 188         2014      2.0   Recology Ostrom Road LF Inc.     50252.93
# 190         2014      3.0   Recology Ostrom Road LF Inc.     52760.13
# 192         2014      4.0   Recology Ostrom Road LF Inc.     47326.00
# 195         2015      1.0   Recology Ostrom Road LF Inc.     46737.04
# 197         2015      2.0   Recology Ostrom Road LF Inc.     42573.03
# 199         2015      3.0   Recology Ostrom Road LF Inc.     42794.02
# 201         2015      4.0   Recology Ostrom Road LF Inc.     45306.00
# 204         2016      1.0   Recology Ostrom Road LF Inc.     46179.00
# 206         2016      2.0   Recology Ostrom Road LF Inc.     44666.01
# 208         2016      3.0   Recology Ostrom Road LF Inc.     45136.78
# 210         2016      4.0   Recology Ostrom Road LF Inc.     46889.01
# 213         2017      1.0   Recology Ostrom Road LF Inc.     49993.03
# 215         2017      2.0   Recology Ostrom Road LF Inc.     50825.12
# 217         2017      3.0   Recology Ostrom Road LF Inc.     48485.74
# 219         2017      4.0   Recology Ostrom Road LF Inc.     99691.05
#
#      Total ADC  is_data_row
# 7          NaN         True
# 8          NaN         True
# 10         NaN         True
# 11         NaN         True
# 13         NaN         True
# 14         NaN         True
# 15         NaN         True
# 17         NaN         True
# 18         NaN         True
# 21         NaN         True
# 23         NaN         True
# 24         NaN         True
# 26         NaN         True
# 27         NaN         True
# 29         NaN         True
# 30         NaN         True
# 33    26904.00         True
# 35    12134.00         True
# 37     9593.00         True
# 39     5177.00         True
# 42     7685.10         True
# 44     7685.10         True
# 46     7036.00         True
# 48      649.10         True
# 51     2010.00         True
# 53    35562.00         True
# 55     4377.00         True
# 57     2310.00         True
# 60     3140.44         True
# 62     1069.00         True
# ..         ...          ...
# 154    6161.83         True
# 156   10493.96         True
# 159    3368.98         True
# 161    4116.17         True
# 163   11003.29         True
# 165    8251.97         True
# 168    4306.17         True
# 170   18604.32         True
# 172   10257.22         True
# 174    8977.52         True
# 177    4376.39         True
# 179    7355.61         True
# 181    6274.83         True
# 183    4730.45         True
# 186    1685.50         True
# 188    4267.53         True
# 190    6073.46         True
# 192    2357.43         True
# 195    2801.57         True
# 197    4365.05         True
# 199    7218.86         True
# 201    3993.52         True
# 204    2069.86         True
# 206    4741.79         True
# 208    8372.65         True
# 210    3896.32         True
# 213    2225.58         True
# 215    6863.40         True
# 217   10309.84         True
# 219    5216.35         True
#
# [100 rows x 6 columns]

# %%
def make_throttle_hook(timeout=1):
    """
    Returns a response hook function which sleeps for `timeout` seconds if
    response is not coming from the cache.

    From https://requests-cache.readthedocs.io/en/latest/user_guide.html#usage
    """
    def hook(response, *args, **kwargs):
        if not getattr(response, 'from_cache', False):
            print(f'{response} not found in cache. Timeout for {timeout:.3f} s.')
            time.sleep(timeout)
        return response
    return hook

def get_session(rate_max=.5, timeout=None):
    
    timeout = 1 / rate_max

    s = requests_cache.CachedSession()
    s.hooks = {'response': make_throttle_hook(timeout)}
    return s

# %%
def process(df):
    return (df
             .pipe(set_columns, row_idx=4)
             .iloc[5:, :]
             .dropna(axis=1, how='all')
             .assign(is_data_row=lambda d: d['Destination Facility'].notnull())
             .fillna(method='ffill')
             .query('is_data_row')
             .drop(columns=['is_data_row'])
            )

def get_df(resp):
    if resp.ok:
        return pd.read_excel(io.BytesIO(resp.content))
    return pd.DataFrame()

# so ducky...
def get_report(county_id, session=requests):
    params = {'CountyID': int(county_id), 'ReportFormat': 'XLS'}
    # if "no record found", the server should return 404 instead of a 200 response with an empty XLS
    resp = session.post(URL, data=params)
    try:
        df = get_df(resp).pipe(process).assign(county_id=county_id)
    except Exception as e:
        print(e)
    else:
        return df

def get_reports():
    dfs = []
#     sesh = get_session(rate_max=2)
    ids = range(1, 58)
    for county_id in ids:
        df = get_report(county_id)
        if df is not None:
            dfs.append(df)
        else:
            print(f'county_id {county_id} not processed')
        # TODO else append to missed ids?
    return pd.concat(dfs)

def process_whole(df):
#     Destination Facility	Diposal Ton	Quarter	Report Year	Total ADC	Transformation Ton	county_id
    names = {
        'Destination Facility': 'destination_facility',
        'Diposal Ton': 'disposal',
        'Report Year': 'report_year',
        'Quarter': 'report_quarter',
        'Total ADC': 'total_adc',
        'Transformation Ton': 'transformation',
    }
    
    return (df
            .rename(columns=names)
            .fillna(0)
            .astype({'report_quarter': int})
           )

# %%
REPORTS = get_reports()
# Out:
# WARNING *** file size (83805) not 512 + multiple of sector size (512)
# WARNING *** file size (9050) not 512 + multiple of sector size (512)
# single positional indexer is out-of-bounds
# county_id 2 not processed
# WARNING *** file size (24704) not 512 + multiple of sector size (512)
# WARNING *** file size (49724) not 512 + multiple of sector size (512)
# WARNING *** file size (43747) not 512 + multiple of sector size (512)
# WARNING *** file size (42316) not 512 + multiple of sector size (512)
# WARNING *** file size (70569) not 512 + multiple of sector size (512)
# WARNING *** file size (25583) not 512 + multiple of sector size (512)
# WARNING *** file size (39402) not 512 + multiple of sector size (512)
# WARNING *** file size (80939) not 512 + multiple of sector size (512)
# WARNING *** file size (45953) not 512 + multiple of sector size (512)
# WARNING *** file size (22621) not 512 + multiple of sector size (512)
# WARNING *** file size (183139) not 512 + multiple of sector size (512)
# WARNING *** file size (85106) not 512 + multiple of sector size (512)
# WARNING *** file size (234968) not 512 + multiple of sector size (512)
# WARNING *** file size (78668) not 512 + multiple of sector size (512)
# WARNING *** file size (43035) not 512 + multiple of sector size (512)
# WARNING *** file size (67736) not 512 + multiple of sector size (512)
# WARNING *** file size (333252) not 512 + multiple of sector size (512)
# WARNING *** file size (47267) not 512 + multiple of sector size (512)
# WARNING *** file size (47107) not 512 + multiple of sector size (512)
# WARNING *** file size (45719) not 512 + multiple of sector size (512)
# WARNING *** file size (27150) not 512 + multiple of sector size (512)
# WARNING *** file size (62767) not 512 + multiple of sector size (512)
# WARNING *** file size (11179) not 512 + multiple of sector size (512)
# WARNING *** file size (95843) not 512 + multiple of sector size (512)
# WARNING *** file size (85818) not 512 + multiple of sector size (512)
# WARNING *** file size (45908) not 512 + multiple of sector size (512)
# WARNING *** file size (9052) not 512 + multiple of sector size (512)
# single positional indexer is out-of-bounds
# county_id 29 not processed
# WARNING *** file size (86302) not 512 + multiple of sector size (512)
# WARNING *** file size (45809) not 512 + multiple of sector size (512)
# WARNING *** file size (25917) not 512 + multiple of sector size (512)
# WARNING *** file size (148823) not 512 + multiple of sector size (512)
# WARNING *** file size (67687) not 512 + multiple of sector size (512)
# WARNING *** file size (42643) not 512 + multiple of sector size (512)
# WARNING *** file size (233739) not 512 + multiple of sector size (512)
# WARNING *** file size (134011) not 512 + multiple of sector size (512)
# WARNING *** file size (9052) not 512 + multiple of sector size (512)
# single positional indexer is out-of-bounds
# county_id 38 not processed
# WARNING *** file size (88313) not 512 + multiple of sector size (512)
# WARNING *** file size (91435) not 512 + multiple of sector size (512)
# WARNING *** file size (57656) not 512 + multiple of sector size (512)
# WARNING *** file size (112570) not 512 + multiple of sector size (512)
# WARNING *** file size (146987) not 512 + multiple of sector size (512)
# WARNING *** file size (85575) not 512 + multiple of sector size (512)
# WARNING *** file size (63895) not 512 + multiple of sector size (512)
# WARNING *** file size (42283) not 512 + multiple of sector size (512)
# WARNING *** file size (41039) not 512 + multiple of sector size (512)
# WARNING *** file size (61905) not 512 + multiple of sector size (512)
# WARNING *** file size (36792) not 512 + multiple of sector size (512)
# WARNING *** file size (72022) not 512 + multiple of sector size (512)
# WARNING *** file size (9052) not 512 + multiple of sector size (512)
# single positional indexer is out-of-bounds
# county_id 51 not processed
# WARNING *** file size (46547) not 512 + multiple of sector size (512)
# WARNING *** file size (20946) not 512 + multiple of sector size (512)
# WARNING *** file size (79706) not 512 + multiple of sector size (512)
# WARNING *** file size (13449) not 512 + multiple of sector size (512)
# WARNING *** file size (66029) not 512 + multiple of sector size (512)
# WARNING *** file size (60110) not 512 + multiple of sector size (512)
# /home/ludo/miniconda3/envs/catdd/lib/python3.6/site-packages/ipykernel_launcher.py:40: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
REPORTS = REPORTS.pipe(process_whole)
REPORTS
# Out:
#                       destination_facility   disposal  report_quarter  \
# 7    Altamont Landfill & Resource Recovery  396727.00               1
# 8      Tri Cities Recycling & Disposal Fac   67410.00               1
# 9             Vasco Road Sanitary Landfill  111209.00               1
# 11   Altamont Landfill & Resource Recovery  393888.00               2
# 12     Tri Cities Recycling & Disposal Fac   72408.00               2
# 13            Vasco Road Sanitary Landfill  114093.00               2
# 15   Altamont Landfill & Resource Recovery  394990.00               3
# 16     Tri Cities Recycling & Disposal Fac   73940.00               3
# 17            Vasco Road Sanitary Landfill  122358.00               3
# 19   Altamont Landfill & Resource Recovery  383876.00               4
# 20     Tri Cities Recycling & Disposal Fac   69466.00               4
# 21            Vasco Road Sanitary Landfill  117852.00               4
# 24   Altamont Landfill & Resource Recovery  366195.39               1
# 25     Tri Cities Recycling & Disposal Fac   66488.00               1
# 26            Vasco Road Sanitary Landfill   98995.40               1
# 28   Altamont Landfill & Resource Recovery  364886.20               2
# 29     Tri Cities Recycling & Disposal Fac   68965.00               2
# 30            Vasco Road Sanitary Landfill  123029.99               2
# 32   Altamont Landfill & Resource Recovery  376517.63               3
# 33     Tri Cities Recycling & Disposal Fac   69346.00               3
# 34            Vasco Road Sanitary Landfill  121816.24               3
# 36   Altamont Landfill & Resource Recovery  373460.60               4
# 37     Tri Cities Recycling & Disposal Fac   68974.00               4
# 38            Vasco Road Sanitary Landfill  104588.89               4
# 41   Altamont Landfill & Resource Recovery  390114.45               1
# 42     Tri Cities Recycling & Disposal Fac   65090.00               1
# 43            Vasco Road Sanitary Landfill   99918.68               1
# 45   Altamont Landfill & Resource Recovery  376317.66               2
# 46     Tri Cities Recycling & Disposal Fac   70259.00               2
# 47            Vasco Road Sanitary Landfill  111964.17               2
# ..                                     ...        ...             ...
# 214  Univ Of Calif Davis Sanitary Landfill    3013.00               1
# 215           Yolo County Central Landfill   42563.88               1
# 217  Univ Of Calif Davis Sanitary Landfill    2744.00               2
# 218           Yolo County Central Landfill   43671.54               2
# 220           Yolo County Central Landfill   41122.33               3
# 222           Yolo County Central Landfill   39942.31               4
# 225           Yolo County Central Landfill   37368.29               1
# 227           Yolo County Central Landfill   40429.25               2
# 229           Yolo County Central Landfill   40389.08               3
# 231           Yolo County Central Landfill   42770.19               4
# 234           Yolo County Central Landfill   39705.26               1
# 236           Yolo County Central Landfill   41766.04               2
# 238           Yolo County Central Landfill   43519.86               3
# 240           Yolo County Central Landfill   42071.73               4
# 243           Yolo County Central Landfill   41347.03               1
# 245           Yolo County Central Landfill   44027.91               2
# 247           Yolo County Central Landfill   43962.41               3
# 249           Yolo County Central Landfill   43792.29               4
# 252           Yolo County Central Landfill   42947.63               1
# 254           Yolo County Central Landfill   43914.69               2
# 256           Yolo County Central Landfill   46152.15               3
# 258           Yolo County Central Landfill   47380.18               4
# 261           Yolo County Central Landfill   46263.45               1
# 263           Yolo County Central Landfill   49213.89               2
# 265           Yolo County Central Landfill   52148.54               3
# 267           Yolo County Central Landfill   48751.10               4
# 270           Yolo County Central Landfill   50421.13               1
# 272           Yolo County Central Landfill   50736.19               2
# 274           Yolo County Central Landfill   51752.14               3
# 276           Yolo County Central Landfill   55855.69               4
#
#      report_year  total_adc  transformation  county_id
# 7           1995     174.00             0.0          1
# 8           1995     174.00             0.0          1
# 9           1995     174.00             0.0          1
# 11          1995   16991.00             0.0          1
# 12          1995    4379.00             0.0          1
# 13          1995    4379.00             0.0          1
# 15          1995   18181.00             0.0          1
# 16          1995    9951.00             0.0          1
# 17          1995    9951.00             0.0          1
# 19          1995   23069.00             0.0          1
# 20          1995    9848.00             0.0          1
# 21          1995    9848.00             0.0          1
# 24          1996   20869.48             0.0          1
# 25          1996   20869.48             0.0          1
# 26          1996   34914.11             0.0          1
# 28          1996   28643.35             0.0          1
# 29          1996   28643.35             0.0          1
# 30          1996   55570.54             0.0          1
# 32          1996   29628.23             0.0          1
# 33          1996   54419.00             0.0          1
# 34          1996   53100.84             0.0          1
# 36          1996   34809.47             0.0          1
# 37          1996    3829.00             0.0          1
# 38          1996   39188.35             0.0          1
# 41          1997   32142.28             0.0          1
# 42          1997    5197.00             0.0          1
# 43          1997    4061.53             0.0          1
# 45          1997   35276.27             0.0          1
# 46          1997    7261.00             0.0          1
# 47          1997    3062.92             0.0          1
# ..           ...        ...             ...        ...
# 214         2011     625.00             0.0         57
# 215         2011     127.98             0.0         57
# 217         2011      49.00             0.0         57
# 218         2011     376.31             0.0         57
# 220         2011    3237.81             0.0         57
# 222         2011    2487.84             0.0         57
# 225         2012     365.52             0.0         57
# 227         2012     350.62             0.0         57
# 229         2012    2727.24             0.0         57
# 231         2012    1541.28             0.0         57
# 234         2013     523.38             0.0         57
# 236         2013     850.59             0.0         57
# 238         2013    3602.33             0.0         57
# 240         2013    1294.78             0.0         57
# 243         2014     434.97             0.0         57
# 245         2014    6607.69             0.0         57
# 247         2014   17127.16             0.0         57
# 249         2014   11250.12             0.0         57
# 252         2015    8395.68             0.0         57
# 254         2015    1479.39             0.0         57
# 256         2015    6493.72             0.0         57
# 258         2015    5851.87             0.0         57
# 261         2016    4353.46             0.0         57
# 263         2016    3608.37             0.0         57
# 265         2016    1760.39             0.0         57
# 267         2016    2676.47             0.0         57
# 270         2017    7254.54             0.0         57
# 272         2017    6689.69             0.0         57
# 274         2017    6928.64             0.0         57
# 276         2017    6133.20             0.0         57
#
# [13832 rows x 7 columns]

# %%
REPORTS.to_csv('/data/datasets/catdd/clean/calrecycle-disposal-reporting.csv')
